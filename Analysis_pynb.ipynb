# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
  
# Making data frame from the csv file
df = pd.read_csv("/content/GraphAnalysis.csv")
  
# To find the correlation among
# the columns using kendall method
df.corr(method ='kendall')
# Out:
#                                   Id  Label  ...  eigencentrality  modularity_class
# Id                          1.000000    NaN  ...        -0.447599          0.020378
# Label                            NaN    NaN  ...              NaN               NaN
# timeset                          NaN    NaN  ...              NaN               NaN
# indegree                   -0.431119    NaN  ...         0.858887         -0.014139
# outdegree                   0.416024    NaN  ...        -0.199203         -0.062298
# Degree                     -0.007598    NaN  ...         0.393191         -0.056644
# weighted indegree          -0.431119    NaN  ...         0.858887         -0.014139
# weighted outdegree          0.416024    NaN  ...        -0.199203         -0.062298
# Weighted Degree            -0.007598    NaN  ...         0.393191         -0.056644
# Eccentricity                0.483696    NaN  ...        -0.247768         -0.089532
# ...

# %%
df_centralities_degrees=df[["indegree","outdegree",	"Degree","eigencentrality","betweenesscentrality","closnesscentrality"]]

# %%
df_centralities_degrees.corr(method ='kendall')
# Out:
#                       indegree  ...  closnesscentrality
# indegree              1.000000  ...           -0.165288
# outdegree            -0.192529  ...            0.242219
# Degree                0.469174  ...            0.021784
# eigencentrality       0.858887  ...           -0.162758
# betweenesscentrality  0.466065  ...            0.212899
# closnesscentrality   -0.165288  ...            1.000000
#
# [6 rows x 6 columns]

# %%
df_HITS_degrees=df[["indegree","outdegree",	"Degree",	"Authority","Hub","pageranks"]]

# %%
df_HITS_degrees.corr(method ='kendall')
# Out:
#            indegree  outdegree    Degree  Authority       Hub  pageranks
# indegree   1.000000  -0.192529  0.469174   0.474219 -0.010552   0.810096
# outdegree -0.192529   1.000000  0.486478   0.053553  0.488156  -0.276248
# Degree     0.469174   0.486478  1.000000   0.377125  0.350814   0.302974
# Authority  0.474219   0.053553  0.377125   1.000000  0.327592   0.323523
# Hub       -0.010552   0.488156  0.350814   0.327592  1.000000  -0.094669
# pageranks  0.810096  -0.276248  0.302974   0.323523 -0.094669   1.000000

# %%
df2=df[["strongcompnum","modularity_class","clustering"]]
df2.corr(method="kendall")
# Out:
#                   strongcompnum  modularity_class  clustering
# strongcompnum          1.000000          0.053526   -0.070393
# modularity_class       0.053526          1.000000   -0.043608
# clustering            -0.070393         -0.043608    1.000000
